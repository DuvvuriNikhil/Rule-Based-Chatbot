# %%
intents = {
    "greeting": {
        "patterns": ["hi", "hello", "hey"],
        "responses": ["Hello!", "Hi there!", "Hey!"]
    },
    "price_query": {
        "patterns": ["price", "cost", "rate"],
        "responses": ["Please tell me the commodity name."]
    },
    "goodbye": {
        "patterns": ["bye", "exit"],
        "responses": ["Goodbye!", "See you later!"]
    }
}

commodities = {
    "apple":   120,
    "banana":  40,
    "carrot":  35,
    "milk":    55,
    "bread":   45,
    "egg":     6,
    "spinach": 30,
    "cabbage": 25,
    "corn":    20,
    "oats":    70,
    "beans":   90,
    "peas":    50
}

# %%
import random

def get_intent(user_input):
    user_input = user_input.lower()
    for intent, data in intents.items():
        for pattern in data["patterns"]:
            if pattern in user_input:
                return intent
    return "unknown"

def get_commodity_price(user_input):
    user_input = user_input.lower()
    for commodity, price in commodities.items():
        if commodity in user_input:
            return commodity, price
    return None, None

def chatbot():
    waiting_for_commodity = False

    while True:
        user_input = input("User: ")
        intent = get_intent(user_input)

        if waiting_for_commodity:
            commodity, price = get_commodity_price(user_input)
            if commodity:
                print(f"Bot: The price of {commodity} is Rs.{price}/kg.")
                waiting_for_commodity = False
                continue
            else:
                print("Bot: Sorry, I don't have the price for that commodity.")
                waiting_for_commodity = False
                continue

        if intent == "price_query":
            commodity, price = get_commodity_price(user_input)
            if commodity:
                print(f"Bot: The price of {commodity} is Rs.{price}/kg.")
            else:
                response = random.choice(intents[intent]["responses"])
                print("Bot:", response)
                waiting_for_commodity = True

        elif intent == "unknown":
            print("Bot: I didn't understand that.")
        else:
            response = random.choice(intents[intent]["responses"])
            print("Bot:", response)

        if intent == "goodbye":
            break

chatbot()
# Out:
# User: hello
# Bot: Hi there!
# User: what is the price of an egg?
# Bot: The price of egg is Rs.6/kg.
# User: what is the price of peas
# Bot: The price of peas is Rs.50/kg.
# User: rate of apple
# Bot: The price of apple is Rs.120/kg.
# User: cost of banana
# Bot: The price of banana is Rs.40/kg.
# User: spinach
# Bot: I didn't understand that.
# User: cost
# Bot: Please tell me the commodity name.
# User: spinach
# Bot: The price of spinach is Rs.30/kg.
# User: Bye
# Bot: See you later!
